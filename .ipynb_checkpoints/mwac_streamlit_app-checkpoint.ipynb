# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.23.1-py2.py3-none-any.whl (8.9 MB)
#      |████████████████████████████████| 8.9 MB 855 kB/s eta 0:00:01
# Requirement already satisfied: packaging<24,>=14.1 in /usr/local/lib/python3.7/site-packages (from streamlit) (23.2)
# Collecting cachetools<6,>=4.0
#   Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Collecting pydeck<1,>=0.1.dev5
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      |████████████████████████████████| 4.8 MB 24.5 MB/s eta 0:00:01
# Collecting toml<2
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /usr/local/lib/python3.7/site-packages (from streamlit) (6.7.0)
# Collecting protobuf<5,>=3.20
#   Downloading protobuf-4.24.4-py3-none-any.whl (175 kB)
#      |████████████████████████████████| 175 kB 33.6 MB/s eta 0:00:01
# Requirement already satisfied: pyarrow>=4.0 in /usr/local/lib/python3.7/site-packages (from streamlit) (12.0.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.7/site-packages (from streamlit) (6.0.3)
# Collecting tenacity<9,>=8.0.0
#   Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.7/site-packages (from streamlit) (1.17.0)
# Requirement already satisfied: python-dateutil<3,>=2 in /usr/local/lib/python3.7/site-packages (from streamlit) (2.8.0)
# Collecting validators<1,>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
# Collecting rich<14,>=10.11.0
#   Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#      |████████████████████████████████| 240 kB 26.5 MB/s eta 0:00:01
# Requirement already satisfied: pillow<10,>=6.2.0 in /usr/local/lib/python3.7/site-packages (from streamlit) (9.5.0)
# Collecting pympler<2,>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      |████████████████████████████████| 164 kB 32.4 MB/s eta 0:00:01
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.7/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: pandas<3,>=0.25 in /usr/local/lib/python3.7/site-packages (from streamlit) (0.25.0)
# Requirement already satisfied: requests<3,>=2.4 in /usr/local/lib/python3.7/site-packages (from streamlit) (2.22.0)
# Collecting tzlocal<5,>=1.1
#   Downloading tzlocal-4.3.1-py3-none-any.whl (20 kB)
# Collecting blinker<2,>=1.0.0
#   Downloading blinker-1.6.3-py3-none-any.whl (13 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.1 in /usr/local/lib/python3.7/site-packages (from streamlit) (4.7.1)
# Collecting gitpython!=3.1.19,<4,>=3
#   Downloading GitPython-3.1.41-py3-none-any.whl (196 kB)
#      |████████████████████████████████| 196 kB 21.4 MB/s eta 0:00:01
# Collecting altair<6,>=4.0
#   Downloading altair-5.0.1-py3-none-any.whl (471 kB)
#      |████████████████████████████████| 471 kB 48.5 MB/s eta 0:00:01
# Requirement already satisfied: jinja2>=2.10.1 in /usr/local/lib/python3.7/site-packages (from pydeck<1,>=0.1.dev5->streamlit) (2.10.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil<3,>=2->streamlit) (1.12.0)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.7/site-packages (from validators<1,>=0.2->streamlit) (4.4.0)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 5.9 MB/s  eta 0:00:01
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading pygments-2.17.2-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 26.3 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/site-packages (from pandas<3,>=0.25->streamlit) (2019.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests<3,>=2.4->streamlit) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests<3,>=2.4->streamlit) (1.25.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests<3,>=2.4->streamlit) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests<3,>=2.4->streamlit) (3.0.4)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting backports.zoneinfo; python_version < "3.9"
#   Downloading backports.zoneinfo-0.2.1-cp37-cp37m-macosx_10_14_x86_64.whl (35 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 4.1 MB/s  eta 0:00:01
# Collecting toolz
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 5.0 MB/s  eta 0:00:01
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.7/site-packages (from altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/site-packages (from jinja2>=2.10.1->pydeck<1,>=0.1.dev5->streamlit) (1.1.1)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting tzdata; python_version >= "3.6"
#   Downloading tzdata-2023.4-py2.py3-none-any.whl (346 kB)
#      |████████████████████████████████| 346 kB 35.0 MB/s eta 0:00:01
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.7/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.15.4)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (19.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (46.0.0)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19567 sha256=436fd33061c7488944afa57794b18902aa80fbe644e3656deb57774c245c171b
#   Stored in directory: /Users/djf2150/Library/Caches/pip/wheels/5f/55/ab/36a76989f7f88d9ca7b1f68da6d94252bb6a8d6ad4f18e04e9
# Successfully built validators
# Installing collected packages: cachetools, pydeck, toml, protobuf, tenacity, validators, mdurl, markdown-it-py, pygments, rich, pympler, tzdata, backports.zoneinfo, pytz-deprecation-shim, tzlocal, blinker, smmap, gitdb, gitpython, toolz, altair, streamlit
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.4.2
#     Uninstalling Pygments-2.4.2:
#       Successfully uninstalled Pygments-2.4.2
# Successfully installed altair-5.0.1 backports.zoneinfo-0.2.1 blinker-1.6.3 cachetools-5.3.2 gitdb-4.0.11 gitpython-3.1.41 markdown-it-py-2.2.0 mdurl-0.1.2 protobuf-4.24.4 pydeck-0.8.1b0 pygments-2.17.2 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 rich-13.7.0 smmap-5.0.1 streamlit-1.23.1 tenacity-8.2.3 toml-0.10.2 toolz-0.12.0 tzdata-2023.4 tzlocal-4.3.1 validators-0.20.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import pandas as pd
from datetime import datetime, timedelta

# %% [markdown]
# ### Data Preparation
# 1. Replace missing values with 0
# 2. Create a 'Winter' identifier (e.g. 2023-2024)
# 3. Create an 'inches' column from the existing 'centimeter' column

# %%
df = pd.read_csv("data/hermit_lake_snowdepth.csv")

# fill missing values with NA
df = df.fillna(0) # replace missing values with 0

# extract day, month, and year from date
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day
df['month_day'] = df['month'].astype(str) + '-' + df['day'].astype(str)

# function to ascertain winter (eg 2023-2024)
def get_winter(X):
    winter_list = []
    
    # loop over all rows in dataframe
    for index, row in X.iterrows():     
        
        # if month is july - december generate '{year}-{year+1}'
        if row['month'] > 6:
            winter_list.append(str(row['year']) + '-' + str(row['year']+1))
        
        # if month is january - june generate '{year-1}-{year}'
        else:
            winter_list.append(str(row['year']-1) + '-' + str(row['year']))

    return winter_list


# function to assign the Nth day of winter (required for visualization)
def assign_day(date_series):
    # Convert the series of date strings to datetime objects
    date_series = pd.to_datetime(date_series, errors='coerce')
    
    # Create a reference date for November 1st of each year
    reference_dates = date_series.apply(lambda date: pd.Timestamp(date.year, 11, 1))
    
    # Calculate the number of days between each date and the corresponding reference date
    days_difference = (date_series - reference_dates).dt.days + 1
    
    # If the result is negative, consider it as days remaining in the previous year
    days_difference[days_difference < 1] += 365
    
    return days_difference
    
df['winter'] = get_winter(df)
df['day_of_winter'] = assign_day(df['date'])

df.to_csv("data/cleaned_hermit_lake_snowdepth.csv")

# %%
df
# Out:
#            date  depth_cm  year  month  day month_day     winter  \
# 0    2008-11-01       0.0  2008     11    1      11-1  2008-2009
# 1    2008-11-02       0.0  2008     11    2      11-2  2008-2009
# 2    2008-11-03       0.0  2008     11    3      11-3  2008-2009
# 3    2008-11-04       0.0  2008     11    4      11-4  2008-2009
# 4    2008-11-05       0.0  2008     11    5      11-5  2008-2009
# ...         ...       ...   ...    ...  ...       ...        ...
# 1211 2024-01-19      90.0  2024      1   19      1-19  2023-2024
# 1212 2024-01-20      90.0  2024      1   20      1-20  2023-2024
# 1213 2024-01-21      93.0  2024      1   21      1-21  2023-2024
# 1214 2024-01-22      89.0  2024      1   22      1-22  2023-2024
# 1215 2024-01-23      85.0  2024      1   23      1-23  2023-2024
#
#       day_of_winter
# 0                 1
# 1                 2
# 2                 3
# 3                 4
# 4                 5
# ...             ...
# 1211             79
# 1212             80
# 1213             81
# 1214             82
# 1215             83
#
# [1216 rows x 8 columns]

# %% [markdown]
# ### Generate historical averages

# %%
historical_averages = df.groupby('day_of_winter')['depth_cm'].mean().reset_index()
historical_averages = historical_averages.sort_values(['day_of_winter'])

historical_averages.to_csv("data/historical_averages.csv")

# %%
historical_averages
# Out:
#      day_of_winter  depth_cm
# 0                1  0.000000
# 1                2  0.000000
# 2                3  0.000000
# 3                4  0.000000
# 4                5  0.000000
# ..             ...       ...
# 207            208  3.333333
# 208            209  0.000000
# 209            210  0.000000
# 210            211  0.000000
# 211            212  0.000000
#
# [212 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import datetime
import numpy as np

plt.plot(historical_averages.day_of_winter,historical_averages.depth_cm)
plt.show()

# %%
# Display the DataFrame
st.write("Snow Depth Data:")
st.dataframe(df)

# Plot the line chart
st.write("Snow Depth Over Time:")
st.line_chart(df.set_index('date')['depth_cm'])
# Out:
# 2024-01-23 21:05:26.176
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py [ARGUMENTS]
# /usr/local/lib/python3.7/site-packages/pyarrow/pandas_compat.py:571: UserWarning: pyarrow requires pandas 1.0.0 or above, pandas 0.25.0 is installed. Therefore, pandas-specific integration is not used.
#   columns)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-3490c6d23f91> in <module>
#       1 # Display the DataFrame
#       2 st.write("Snow Depth Data:")
# ----> 3 st.dataframe(df)
#       4
#       5 # Plot the line chart
#
# /usr/local/lib/python3.7/site-packages/streamlit/runtime/metrics_util.py in wrapped_func(*args, **kwargs)
#     354                 _LOGGER.debug("Failed to collect command telemetry", exc_info=ex)
#     355         try:
# --> 356             result = non_optional_func(*args, **kwargs)
#     357         finally:
#     358             # Activate tracking again if command executes without any exceptions
#
# /usr/local/lib/python3.7/site-packages/streamlit/elements/dataframe_selector.py in dataframe(self, data, width, height, use_container_width, hide_index, column_order, column_config)
#     185                 hide_index=hide_index,
#     186                 column_order=column_order,
# --> 187                 column_config=column_config,
#     188             )
#     189         else:
#
# /usr/local/lib/python3.7/site-packages/streamlit/runtime/metrics_util.py in wrapped_func(*args, **kwargs)
#     354                 _LOGGER.debug("Failed to collect command telemetry", exc_info=ex)
#     355         try:
# --> 356             result = non_optional_func(*args, **kwargs)
#     357         finally:
#     358             # Activate tracking again if command executes without any exceptions
#
# /usr/local/lib/python3.7/site-packages/streamlit/elements/arrow.py in _arrow_dataframe(self, data, width, height, use_container_width, hide_index, column_order, column_config)
#     186             )
#     187             # Serialize the data to bytes:
# --> 188             proto.data = type_util.data_frame_to_bytes(data_df)
#     189
#     190         if hide_index is not None:
#
# /usr/local/lib/python3.7/site-packages/streamlit/type_util.py in data_frame_to_bytes(df)
#     754     """
#     755     try:
# --> 756         table = pa.Table.from_pandas(df)
#     757     except (pa.ArrowTypeError, pa.ArrowInvalid, pa.ArrowNotImplementedError) as ex:
#     758         _LOGGER.info(
#
# /usr/local/lib/python3.7/site-packages/pyarrow/table.pxi in pyarrow.lib.Table.from_pandas()
#
# /usr/local/lib/python3.7/site-packages/pyarrow/pandas_compat.py in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     569      columns_to_convert,
#     570      convert_fields) = _get_columns_to_convert(df, schema, preserve_index,
# --> 571                                                columns)
#     572
#     573     # NOTE(wesm): If nthreads=None, then we use a heuristic to decide whether
#
# /usr/local/lib/python3.7/site-packages/pyarrow/pandas_compat.py in _get_columns_to_convert(df, schema, preserve_index, columns)
#     383     for i, index_level in enumerate(index_levels):
#     384         name = _index_level_name(index_level, i, column_names)
# --> 385         if (isinstance(index_level, _pandas_api.pd.RangeIndex) and
#     386                 preserve_index is None):
#     387             descr = _get_range_index_descriptor(index_level)
#
# /usr/local/lib/python3.7/site-packages/pyarrow/pandas-shim.pxi in pyarrow.lib._PandasAPIShim.pd.__get__()
#
# /usr/local/lib/python3.7/site-packages/pyarrow/pandas-shim.pxi in pyarrow.lib._PandasAPIShim._check_import()
#
# /usr/local/lib/python3.7/site-packages/pyarrow/pandas-shim.pxi in pyarrow.lib._PandasAPIShim._import_pandas()
#
# ImportError: pyarrow requires pandas 1.0.0 or above, pandas 0.25.0 is installed

# %%
st.title('Historical Average Snow Depth - Mt. Washington')
